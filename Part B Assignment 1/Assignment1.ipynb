# %%
import pandas as pd

# %%
#import CSV file

# %%
df = pd.read_csv("dataset_Facebook.csv", sep=";");
df
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# 5              139441  Status         2          12             1          9
# 6              139441   Photo         3          12             1          3
# 7              139441   Photo         3          12             7          9
# 8              139441  Status         2          12             7          3
# 9              139441   Photo         3          12             6         10
# 10             139441  Status         2          12             5         10
# ...

# %%
df.shape
# Out:
# (500, 19)

# %%
df.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
# 1.Create Data Subsets

# %%
df1 = df[['Page total likes','Type','Post Month','like']].loc[0:15]

# %%
df1
# Out:
#     Page total likes    Type  Post Month    like
# 0             139441   Photo          12    79.0
# 1             139441  Status          12   130.0
# 2             139441   Photo          12    66.0
# 3             139441   Photo          12  1572.0
# 4             139441   Photo          12   325.0
# 5             139441  Status          12   152.0
# 6             139441   Photo          12   249.0
# 7             139441   Photo          12   325.0
# 8             139441  Status          12   161.0
# 9             139441   Photo          12   113.0
# 10            139441  Status          12   233.0
# 11            139441   Photo          12    88.0
# 12            139441   Photo          12    90.0
# 13            139441   Photo          12   137.0
# 14            138414   Photo          12   577.0
# 15            138414  Status          12    86.0

# %%
df2 = df[['Page total likes','Type','Post Month','like']].loc[16:30]

# %%
df2
# Out:
#     Page total likes    Type  Post Month   like
# 16            138414   Photo          12   40.0
# 17            138414   Photo          12  678.0
# 18            138414  Status          12   54.0
# 19            138414   Photo          12   34.0
# 20            138414   Photo          12   66.0
# 21            138414   Photo          12    0.0
# 22            138414    Link          12   16.0
# 23            138414   Photo          12   72.0
# 24            138414  Status          12   99.0
# 25            138458  Status          12   88.0
# 26            138458  Status          12  412.0
# 27            138458   Photo          12  100.0
# 28            138895   Photo          12  523.0
# 29            138895   Video          12  143.0
# 30            138895   Photo          12  107.0

# %%
df3 = df[['Page total likes','Type','Post Month','like']].loc[31:60]

# %%
df3
# Out:
#     Page total likes    Type  Post Month   like
# 31            138895   Photo          12   27.0
# 32            138895   Photo          12  155.0
# 33            138895   Photo          12   98.0
# 34            138895   Photo          12   56.0
# 35            138895   Photo          12  172.0
# 36            138895   Photo          12   96.0
# 37            138895   Photo          12   76.0
# 38            138895  Status          12  227.0
# 39            138895   Photo          12   44.0
# 40            138895  Status          12  216.0
# 41            138895    Link          12  187.0
# 42            138353   Photo          12   26.0
# 43            138353    Link          12   29.0
# 44            138353   Photo          12   47.0
# 45            138353    Link          12   57.0
# 46            138353  Status          12  174.0
# 47            138353    Link          12   18.0
# 48            138353   Photo          12   77.0
# 49            138353    Link          12   12.0
# ...

# %%
# 2.Merge Data

# %%
merge = pd.concat([df1,df2,df3])

# %%
merge
# Out:
#     Page total likes    Type  Post Month    like
# 0             139441   Photo          12    79.0
# 1             139441  Status          12   130.0
# 2             139441   Photo          12    66.0
# 3             139441   Photo          12  1572.0
# 4             139441   Photo          12   325.0
# 5             139441  Status          12   152.0
# 6             139441   Photo          12   249.0
# 7             139441   Photo          12   325.0
# 8             139441  Status          12   161.0
# 9             139441   Photo          12   113.0
# 10            139441  Status          12   233.0
# 11            139441   Photo          12    88.0
# 12            139441   Photo          12    90.0
# 13            139441   Photo          12   137.0
# 14            138414   Photo          12   577.0
# 15            138414  Status          12    86.0
# 16            138414   Photo          12    40.0
# 17            138414   Photo          12   678.0
# ...

# %%
# 3.Sort Data

# %%
sort_values = merge.sort_values('like',ascending = False)
sort_values
# Out:
#     Page total likes    Type  Post Month    like
# 3             139441   Photo          12  1572.0
# 17            138414   Photo          12   678.0
# 14            138414   Photo          12   577.0
# 28            138895   Photo          12   523.0
# 26            138458  Status          12   412.0
# 4             139441   Photo          12   325.0
# 7             139441   Photo          12   325.0
# 51            138329   Photo          11   285.0
# 6             139441   Photo          12   249.0
# 10            139441  Status          12   233.0
# 38            138895  Status          12   227.0
# 40            138895  Status          12   216.0
# 52            138329   Photo          11   202.0
# 41            138895    Link          12   187.0
# 46            138353  Status          12   174.0
# 35            138895   Photo          12   172.0
# 56            138329   Photo          11   164.0
# 8             139441  Status          12   161.0
# ...

# %%
# 4.Transposing Data

# %%
df.transpose()
#convert rows to columns and columns to rows
# Out:
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                     0       0       0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
# 5.Shape and reshape Data

# %%
# Shape
df.shape
# Out:
# (500, 19)

# %%
# Reshaping
pivot_table = pd.pivot_table(df,index = ['Type','Category'], values='comment')
print(pivot_table)
# Out:
#                    comment
# Type   Category
# Link   1          2.900000
#        2          2.000000
#        3          2.000000
# Photo  1          5.897297
#        2         11.692308
#        3          6.913333
# Status 1          4.333333
#        2          9.921053
#        3          2.750000
# Video  1         12.285714
